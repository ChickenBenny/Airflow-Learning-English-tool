# %%
import requests
import pandas as pd

YOUTUBE_API_KEY = 'AIzaSyCjrRrjV8qLlTkxNqMbAn8jjlDqXksU_Ec'

# %%
id = 'vSmR5kOKPdY'
url = f'https://www.googleapis.com/youtube/v3/videos?id={id}&key={YOUTUBE_API_KEY}&part=snippet'
response = requests.get(url)
response = response.json()
response
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'yRh-C-hxvPAbFKb66rqqwzs4Jz0',
#  'items': [{'kind': 'youtube#video',
#    'etag': '_phvJo_l1sO28H-u0n72P4ih5vc',
#    'id': 'vSmR5kOKPdY',
#    'snippet': {'publishedAt': '2022-08-26T13:00:38Z',
#     'channelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ',
#     'title': '【薇薇】鏡子是人類最偉大的發明 02搖 2 Phut Hon',
#     'description': '喜歡影片的話幫我按個【喜歡👍】和【訂閱💟】\n開啟【小鈴鐺🔔】才不會錯過新片通知唷！非常感謝 🙏\n影片投稿 ► https://forms.gle/1sRmbEMRhdU83KoLA\n\n薇薇 Twitch ► https://bit.ly/3jyBpBL\n薇薇 YouTube ► https://bit.ly/37N6uyO\n薇薇 Instagram ► https://bit.ly/3uP6aJb\n薇薇 Facebook ► https://bit.ly/38Jqpix\n\n#薇薇 #西門夜說 #抱歉了西門\n#大傑亂剪\n#twitch #twitchstreamer #twitchclips',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vSmR5kOKPdY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vSmR5kOKPdY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vSmR5kOKPdY/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/vSmR5kOKPdY/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/vSmR5kOKPdY/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '大傑亂剪',
#     'categoryId': '24',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'zh-TW',
#     'localized': {'title': '【薇薇】鏡子是人類最偉大的發明 02搖 2 Phut Hon',
#      'description': '喜歡影片的話幫我按個【喜歡👍】和【訂閱💟】\n開啟【小鈴鐺🔔】才不會錯過新片通知唷！非常感謝 🙏\n影片投稿 ► https://forms.gle/1sRmbEMRhdU83KoLA\n\n薇薇 Twitch ► https://bit.ly/3jyBpBL\n薇薇 YouTube ► https://bit.ly/37N6uyO\n薇薇 Instagram ► https://bit.ly/3uP6aJb\n薇薇 Facebook ► https://bit.ly/38Jqpix\n\n#薇薇 #西門夜說 #抱歉了西門\n#大傑亂剪\n#twitch #twitchstreamer #twitchclips'},
#     'defaultAudioLanguage': 'zh-TW'}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
(response['items'][0]).get('snippet').get('channelTitle')
# Out:
# '大傑亂剪'

# %%
((response['items'][0])['snippet'])['channelId']
# Out:
# 'UCA33Z_T-w17Jf-4vnIwRGsQ'

# %%
channelId = (response['items'][0]).get('snippet').get('channelId')
channelId
# Out:
# 'UCA33Z_T-w17Jf-4vnIwRGsQ'

# %%
url = f'https://www.googleapis.com/youtube/v3/channels?part=contentDetails&id={channelId}&key={YOUTUBE_API_KEY}'
response = requests.get(url)
channel_cred = response.json()
channel_cred
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'SSIjGbBWLMhxuiyM9gLeJuWREUI',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'sRCGH14Ih5fed-8Y0kOSqk71CQQ',
#    'id': 'UCA33Z_T-w17Jf-4vnIwRGsQ',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUA33Z_T-w17Jf-4vnIwRGsQ'}}}]}

# %%
play_list_id = channel_cred['items'][0].get('contentDetails').get('relatedPlaylists').get('uploads')

# %%
url = f'https://www.googleapis.com/youtube/v3/playlistItems?part=snippet,contentDetails,status&playlistId={play_list_id}&key={YOUTUBE_API_KEY}&maxResults=20'
response = requests.get(url)
play_list = response.json()
play_list
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': '2vU4g5IXPxth0_P2r9gcBRveuQ0',
#  'nextPageToken': 'EAAaBlBUOkNCUQ',
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': 'HdEDeEbe0lFFIAw7XWnNZujQgGM',
#    'id': 'VVVBMzNaX1QtdzE3SmYtNHZuSXdSR3NRLjJiVXlFY0NGclJ3',
#    'snippet': {'publishedAt': '2022-08-27T13:00:03Z',
#     'channelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ',
#     'title': '【庭米】這樣夠晃鬆嗎 02搖 2 Phut Hon',
#     'description': '喜歡影片的話幫我按個【喜歡👍】和【訂閱💟】\n開啟【小鈴鐺🔔】才不會錯過新片通知唷！非常感謝 🙏\n影片投稿 ► https://forms.gle/1sRmbEMRhdU83KoLA\n\n庭米 Twitch ► https://bit.ly/3NuamUZ\n庭米 YouTube ► https://bit.ly/38FKUx3\n庭米 Instagram ► https://bit.ly/3luxlmT\n庭米 Facebook ► https://bit.ly/3MB3O79\n\n#庭米\n#大傑亂剪\n#twitch #twitchstreamer #twitchclips',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/2bUyEcCFrRw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/2bUyEcCFrRw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/2bUyEcCFrRw/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/2bUyEcCFrRw/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/2bUyEcCFrRw/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '大傑亂剪',
#     'playlistId': 'UUA33Z_T-w17Jf-4vnIwRGsQ',
#     'position': 0,
#     'resourceId': {'kind': 'youtube#video', 'videoId': '2bUyEcCFrRw'},
#     'videoOwnerChannelTitle': '大傑亂剪',
#     'videoOwnerChannelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ'},
#    'contentDetails': {'videoId': '2bUyEcCFrRw',
#     'videoPublishedAt': '2022-08-27T13:00:03Z'},
#    'status': {'privacyStatus': 'public'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'NiMBFILAH711NMM3gkUVX9eR9FM',
#    'id': 'VVVBMzNaX1QtdzE3SmYtNHZuSXdSR3NRLndPTGp5WlNiM0ln',
#    'snippet': {'publishedAt': '2022-08-27T10:00:39Z',
#     'channelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ',
#     'title': '【芝衣x泥泥汝】躺下來組家具 這是免費能看的嗎',
#     'description': '喜歡影片的話幫我按個【喜歡👍】和【訂閱💟】\n開啟【小鈴鐺🔔】才不會錯過新片通知唷！非常感謝 🙏\n影片投稿 ► https://forms.gle/1sRmbEMRhdU83KoLA\n\n芝衣 Twitch ► https://bit.ly/3MUNBJw\n芝衣 YouTube ► https://bit.ly/3P9rD7o\n芝衣 Instagram ► https://bit.ly/3kULVni\n芝衣 Facebook ► https://bit.ly/3vVbFGv\n\n泥泥汝 Twitch ► https://bit.ly/3AfNOlQ\n泥泥汝 YouTube ► https://bit.ly/3AaeBAc\n泥泥汝 Instagram ► https://bit.ly/3wmyVx7\n泥泥汝 Facebook ► https://bit.ly/3PJPsSu\n\n#芝衣 #泥泥汝\n#大傑亂剪\n#twitch #twitchstreamer #twitchclips',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wOLjyZSb3Ig/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/wOLjyZSb3Ig/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/wOLjyZSb3Ig/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/wOLjyZSb3Ig/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/wOLjyZSb3Ig/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '大傑亂剪',
#     'playlistId': 'UUA33Z_T-w17Jf-4vnIwRGsQ',
#     'position': 1,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'wOLjyZSb3Ig'},
#     'videoOwnerChannelTitle': '大傑亂剪',
#     'videoOwnerChannelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ'},
#    'contentDetails': {'videoId': 'wOLjyZSb3Ig',
#     'videoPublishedAt': '2022-08-27T10:00:39Z'},
#    'status': {'privacyStatus': 'public'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'wnybVNVXpfkpUqpkB2MpG7SvsDE',
#    'id': 'VVVBMzNaX1QtdzE3SmYtNHZuSXdSR3NRLnZTbVI1a09LUGRZ',
#    'snippet': {'publishedAt': '2022-08-26T13:00:38Z',
#     'channelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ',
#     'title': '【薇薇】鏡子是人類最偉大的發明 02搖 2 Phut Hon',
#     'description': '喜歡影片的話幫我按個【喜歡👍】和【訂閱💟】\n開啟【小鈴鐺🔔】才不會錯過新片通知唷！非常感謝 🙏\n影片投稿 ► https://forms.gle/1sRmbEMRhdU83KoLA\n\n薇薇 Twitch ► https://bit.ly/3jyBpBL\n薇薇 YouTube ► https://bit.ly/37N6uyO\n薇薇 Instagram ► https://bit.ly/3uP6aJb\n薇薇 Facebook ► https://bit.ly/38Jqpix\n\n#薇薇 #西門夜說 #抱歉了西門\n#大傑亂剪\n#twitch #twitchstreamer #twitchclips',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/vSmR5kOKPdY/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/vSmR5kOKPdY/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/vSmR5kOKPdY/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/vSmR5kOKPdY/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/vSmR5kOKPdY/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '大傑亂剪',
#     'playlistId': 'UUA33Z_T-w17Jf-4vnIwRGsQ',
#     'position': 2,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'vSmR5kOKPdY'},
#     'videoOwnerChannelTitle': '大傑亂剪',
#     'videoOwnerChannelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ'},
#    'contentDetails': {'videoId': 'vSmR5kOKPdY',
#     'videoPublishedAt': '2022-08-26T13:00:38Z'},
#    'status': {'privacyStatus': 'public'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'ip2qRQ8MD9tDMpW6cXumnb1SzL0',
#    'id': 'VVVBMzNaX1QtdzE3SmYtNHZuSXdSR3NRLlNJeGR2bm1JQkow',
#    'snippet': {'publishedAt': '2022-08-26T10:30:07Z',
#     'channelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ',
#     'title': '【豆豆】整形看起來會差很多嗎',
#     'description': '喜歡影片的話幫我按個【喜歡👍】和【訂閱💟】\n開啟【小鈴鐺🔔】才不會錯過新片通知唷！非常感謝 🙏\n影片投稿 ► https://forms.gle/1sRmbEMRhdU83KoLA\n\n豆豆 Twitch ► https://bit.ly/3zG5lTA\n豆豆 YouTube ► https://bit.ly/3xUYTJv\n豆豆 Instagram ► https://bit.ly/3viU4rZ\n豆豆 Facebook ► https://bit.ly/37DHQkJ\n\n#豆豆 #豆豆在這裡\n#大傑亂剪\n#twitch #twitchstreamer #twitchclips',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/SIxdvnmIBJ0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/SIxdvnmIBJ0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/SIxdvnmIBJ0/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '大傑亂剪',
#     'playlistId': 'UUA33Z_T-w17Jf-4vnIwRGsQ',
#     'position': 3,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'SIxdvnmIBJ0'},
#     'videoOwnerChannelTitle': '大傑亂剪',
#     'videoOwnerChannelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ'},
#    'contentDetails': {'videoId': 'SIxdvnmIBJ0',
#     'videoPublishedAt': '2022-08-26T10:30:07Z'},
#    'status': {'privacyStatus': 'public'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'aahEDC7CDeHwF-aMuzJfvWfac0o',
#    'id': 'VVVBMzNaX1QtdzE3SmYtNHZuSXdSR3NRLjdqYWRJaWs2UG0w',
#    'snippet': {'publishedAt': '2022-08-25T13:00:08Z',
#     'channelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ',
#     'title': '【薇薇】梳子的大小剛剛好 提摩舞',
#     'description': '喜歡影片的話幫我按個【喜歡👍】和【訂閱💟】\n開啟【小鈴鐺🔔】才不會錯過新片通知唷！非常感謝 🙏\n影片投稿 ► https://forms.gle/1sRmbEMRhdU83KoLA\n\n薇薇 Twitch ► https://bit.ly/3jyBpBL\n薇薇 YouTube ► https://bit.ly/37N6uyO\n薇薇 Instagram ► https://bit.ly/3uP6aJb\n薇薇 Facebook ► https://bit.ly/38Jqpix\n\n#薇薇 #西門夜說 #抱歉了西門\n#大傑亂剪\n#twitch #twitchstreamer #twitchclips',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7jadIik6Pm0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7jadIik6Pm0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7jadIik6Pm0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/7jadIik6Pm0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/7jadIik6Pm0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '大傑亂剪',
#     'playlistId': 'UUA33Z_T-w17Jf-4vnIwRGsQ',
#     'position': 4,
#     'resourceId': {'kind': 'youtube#video', 'videoId': '7jadIik6Pm0'},
#     'videoOwnerChannelTitle': '大傑亂剪',
#     'videoOwnerChannelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ'},
#    'contentDetails': {'videoId': '7jadIik6Pm0',
#     'videoPublishedAt': '2022-08-25T13:00:08Z'},
#    'status': {'privacyStatus': 'public'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '_LQgsLzCPnykSsQ9m_pytXZUMQc',
#    'id': 'VVVBMzNaX1QtdzE3SmYtNHZuSXdSR3NRLkQycWV2aGxrZEhV',
#    'snippet': {'publishedAt': '2022-08-25T10:17:05Z',
#     'channelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ',
#     'title': '【芝衣】站起來發現忘了拉',
#     'description': '喜歡影片的話幫我按個【喜歡👍】和【訂閱💟】\n開啟【小鈴鐺🔔】才不會錯過新片通知唷！非常感謝 🙏\n影片投稿 ► https://forms.gle/1sRmbEMRhdU83KoLA\n\n芝衣 Twitch ► https://bit.ly/3MUNBJw\n芝衣 YouTube ► https://bit.ly/3P9rD7o\n芝衣 Instagram ► https://bit.ly/3kULVni\n芝衣 Facebook ► https://bit.ly/3vVbFGv\n\n#芝衣 #芝衣芝衣\n#大傑亂剪\n#twitch #twitchstreamer #twitchclips',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/D2qevhlkdHU/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/D2qevhlkdHU/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/D2qevhlkdHU/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/D2qevhlkdHU/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/D2qevhlkdHU/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '大傑亂剪',
#     'playlistId': 'UUA33Z_T-w17Jf-4vnIwRGsQ',
#     'position': 5,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'D2qevhlkdHU'},
#     'videoOwnerChannelTitle': '大傑亂剪',
#     'videoOwnerChannelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ'},
#    'contentDetails': {'videoId': 'D2qevhlkdHU',
#     'videoPublishedAt': '2022-08-25T10:17:05Z'},
#    'status': {'privacyStatus': 'public'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '4iaDxkE8dkwSICwvY0yJeoBSN9Y',
#    'id': 'VVVBMzNaX1QtdzE3SmYtNHZuSXdSR3NRLjh2eUp1WG1yakEw',
#    'snippet': {'publishedAt': '2022-08-25T10:15:00Z',
#     'channelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ',
#     'title': '【豆豆】想去泰國C麻嗎',
#     'description': '喜歡影片的話幫我按個【喜歡👍】和【訂閱💟】\n開啟【小鈴鐺🔔】才不會錯過新片通知唷！非常感謝 🙏\n影片投稿 ► https://forms.gle/1sRmbEMRhdU83KoLA\n\n豆豆 Twitch ► https://bit.ly/3zG5lTA\n豆豆 YouTube ► https://bit.ly/3xUYTJv\n豆豆 Instagram ► https://bit.ly/3viU4rZ\n豆豆 Facebook ► https://bit.ly/37DHQkJ\n\n#豆豆 #豆豆在這裡\n#大傑亂剪\n#twitch #twitchstreamer #twitchclips',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8vyJuXmrjA0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/8vyJuXmrjA0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/8vyJuXmrjA0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/8vyJuXmrjA0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/8vyJuXmrjA0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '大傑亂剪',
#     'playlistId': 'UUA33Z_T-w17Jf-4vnIwRGsQ',
#     'position': 6,
#     'resourceId': {'kind': 'youtube#video', 'videoId': '8vyJuXmrjA0'},
#     'videoOwnerChannelTitle': '大傑亂剪',
#     'videoOwnerChannelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ'},
#    'contentDetails': {'videoId': '8vyJuXmrjA0',
#     'videoPublishedAt': '2022-08-25T10:15:00Z'},
#    'status': {'privacyStatus': 'public'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'JSWiWeaCM4jJmkyVYkFSLpszDXQ',
#    'id': 'VVVBMzNaX1QtdzE3SmYtNHZuSXdSR3NRLmF1bmRULW1hM3Rn',
#    'snippet': {'publishedAt': '2022-08-24T13:00:02Z',
#     'channelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ',
#     'title': '【妲妲】你眼睛跟的上嗎 幻影★ギャラクティカ',
#     'description': '💗【工商時間】推薦超辣、性感、美腿正妹直播交友app\n🔥  footseen直播app下載 👉 https://bit.ly/3PbD0L0\n💰 使用上方連結安裝註冊即可免費獲得點數（露水）\n\n喜歡影片的話幫我按個【喜歡👍】和【訂閱💟】\n開啟【小鈴鐺🔔】才不會錯過新片通知唷！非常感謝 🙏\n影片投稿 ► https://forms.gle/1sRmbEMRhdU83KoLA\n\n妲妲 Twitch ► https://bit.ly/3ERyfTa\n妲妲 YouTube ► https://bit.ly/3Ozk8qp\n妲妲 Instagram ► https://bit.ly/3vMUWUI\n妲妲 Facebook ► https://bit.ly/3kimewR\n\n#妲妲 #妲妲咬果凍\n#大傑亂剪\n#twitch #twitchstreamer #twitchclips',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/aundT-ma3tg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/aundT-ma3tg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/aundT-ma3tg/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/aundT-ma3tg/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/aundT-ma3tg/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '大傑亂剪',
#     'playlistId': 'UUA33Z_T-w17Jf-4vnIwRGsQ',
#     'position': 7,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'aundT-ma3tg'},
#     'videoOwnerChannelTitle': '大傑亂剪',
#     'videoOwnerChannelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ'},
#    'contentDetails': {'videoId': 'aundT-ma3tg',
#     'videoPublishedAt': '2022-08-24T13:00:02Z'},
#    'status': {'privacyStatus': 'public'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'b033PvjTShLHX3IYs1xEnyASDrs',
#    'id': 'VVVBMzNaX1QtdzE3SmYtNHZuSXdSR3NRLkUtRjNIdlhfelE4',
#    'snippet': {'publishedAt': '2022-08-24T10:30:02Z',
#     'channelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ',
#     'title': '【子喵喵】一個禮拜最多跟男朋友做幾次',
#     'description': '喜歡影片的話幫我按個【喜歡👍】和【訂閱💟】\n開啟【小鈴鐺🔔】才不會錯過新片通知唷！非常感謝 🙏\n影片投稿 ► https://forms.gle/1sRmbEMRhdU83KoLA\n\n子喵喵 Twitch ► https://bit.ly/3xTXcfo\n子喵喵 YouTube ► https://bit.ly/3MqSE4b\n子喵喵 Instagram ► https://bit.ly/36GsXxi\n子喵喵 Facebook ► https://bit.ly/3k3Zfpc\n\n#子喵喵 #子喵\n#大傑亂剪\n#twitch #twitchstreamer #twitchclips',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/E-F3HvX_zQ8/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/E-F3HvX_zQ8/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/E-F3HvX_zQ8/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/E-F3HvX_zQ8/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/E-F3HvX_zQ8/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '大傑亂剪',
#     'playlistId': 'UUA33Z_T-w17Jf-4vnIwRGsQ',
#     'position': 8,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'E-F3HvX_zQ8'},
#     'videoOwnerChannelTitle': '大傑亂剪',
#     'videoOwnerChannelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ'},
#    'contentDetails': {'videoId': 'E-F3HvX_zQ8',
#     'videoPublishedAt': '2022-08-24T10:30:02Z'},
#    'status': {'privacyStatus': 'public'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'XJ7rUAUQluC8X-YFUMuwKywUpkU',
#    'id': 'VVVBMzNaX1QtdzE3SmYtNHZuSXdSR3NRLmF1QTctMFlNWnVJ',
#    'snippet': {'publishedAt': '2022-08-23T13:00:03Z',
#     'channelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ',
#     'title': '【薇薇】鏡子我的超人 狗幹硬 Kokain',
#     'description': '💗【工商時間】推薦超辣、性感、美腿正妹直播交友app\n🔥  footseen直播app下載 👉 https://bit.ly/3PbD0L0\n💰 使用上方連結安裝註冊即可免費獲得點數（露水）\n\n喜歡影片的話幫我按個【喜歡👍】和【訂閱💟】\n開啟【小鈴鐺🔔】才不會錯過新片通知唷！非常感謝 🙏\n影片投稿 ► https://forms.gle/1sRmbEMRhdU83KoLA\n\n薇薇 Twitch ► https://bit.ly/3jyBpBL\n薇薇 YouTube ► https://bit.ly/37N6uyO\n薇薇 Instagram ► https://bit.ly/3uP6aJb\n薇薇 Facebook ► https://bit.ly/38Jqpix\n\n#薇薇 #西門夜說 #抱歉了西門\n#大傑亂剪\n#twitch #twitchstreamer #twitchclips',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/auA7-0YMZuI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/auA7-0YMZuI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/auA7-0YMZuI/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/auA7-0YMZuI/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/auA7-0YMZuI/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '大傑亂剪',
#     'playlistId': 'UUA33Z_T-w17Jf-4vnIwRGsQ',
#     'position': 9,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'auA7-0YMZuI'},
#     'videoOwnerChannelTitle': '大傑亂剪',
#     'videoOwnerChannelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ'},
#    'contentDetails': {'videoId': 'auA7-0YMZuI',
#     'videoPublishedAt': '2022-08-23T13:00:03Z'},
#    'status': {'privacyStatus': 'public'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'cZOdq_AKhfM-F53DIPTjZRHK5bI',
#    'id': 'VVVBMzNaX1QtdzE3SmYtNHZuSXdSR3NRLk91MWFhOXduc0Ew',
#    'snippet': {'publishedAt': '2022-08-22T13:00:11Z',
#     'channelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ',
#     'title': '【薇薇】小露香肩性感鎖骨 狗幹硬 Kokain',
#     'description': '💗【工商時間】推薦超辣、性感、美腿正妹直播交友app\n🔥  footseen直播app下載 👉 https://bit.ly/3PbD0L0\n💰 使用上方連結安裝註冊即可免費獲得點數（露水）\n\n喜歡影片的話幫我按個【喜歡👍】和【訂閱💟】\n開啟【小鈴鐺🔔】才不會錯過新片通知唷！非常感謝 🙏\n影片投稿 ► https://forms.gle/1sRmbEMRhdU83KoLA\n\n薇薇 Twitch ► https://bit.ly/3jyBpBL\n薇薇 YouTube ► https://bit.ly/37N6uyO\n薇薇 Instagram ► https://bit.ly/3uP6aJb\n薇薇 Facebook ► https://bit.ly/38Jqpix\n\n#薇薇 #西門夜說 #抱歉了西門\n#大傑亂剪\n#twitch #twitchstreamer #twitchclips',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/Ou1aa9wnsA0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/Ou1aa9wnsA0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/Ou1aa9wnsA0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/Ou1aa9wnsA0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/Ou1aa9wnsA0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '大傑亂剪',
#     'playlistId': 'UUA33Z_T-w17Jf-4vnIwRGsQ',
#     'position': 10,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'Ou1aa9wnsA0'},
#     'videoOwnerChannelTitle': '大傑亂剪',
#     'videoOwnerChannelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ'},
#    'contentDetails': {'videoId': 'Ou1aa9wnsA0',
#     'videoPublishedAt': '2022-08-22T13:00:11Z'},
#    'status': {'privacyStatus': 'public'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'IHtiQudCiHMEyF3xMgqzJlw6sck',
#    'id': 'VVVBMzNaX1QtdzE3SmYtNHZuSXdSR3NRLjl5eWJjakRxeE1N',
#    'snippet': {'publishedAt': '2022-08-22T13:00:10Z',
#     'channelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ',
#     'title': '【酪梨歐】不要生氣 生氣吃虧是你自己',
#     'description': '喜歡影片的話幫我按個【喜歡👍】和【訂閱💟】\n開啟【小鈴鐺🔔】才不會錯過新片通知唷！非常感謝 🙏\n影片投稿 ► https://forms.gle/1sRmbEMRhdU83KoLA\n\n酪梨歐 Twitch ► https://bit.ly/3GbbMl2\n酪梨歐 YouTube ► https://bit.ly/3sLG9IX\n酪梨歐 Instagram ► https://bit.ly/39LWas1\n酪梨歐 Facebook ► https://bit.ly/39F2vFw\n\n#酪梨歐 #酪梨\n#大傑亂剪\n#twitch #twitchstreamer #twitchclips',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/9yybcjDqxMM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/9yybcjDqxMM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/9yybcjDqxMM/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/9yybcjDqxMM/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/9yybcjDqxMM/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '大傑亂剪',
#     'playlistId': 'UUA33Z_T-w17Jf-4vnIwRGsQ',
#     'position': 11,
#     'resourceId': {'kind': 'youtube#video', 'videoId': '9yybcjDqxMM'},
#     'videoOwnerChannelTitle': '大傑亂剪',
#     'videoOwnerChannelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ'},
#    'contentDetails': {'videoId': '9yybcjDqxMM',
#     'videoPublishedAt': '2022-08-22T13:00:10Z'},
#    'status': {'privacyStatus': 'public'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'HbSWFcXH_RMOtZtPE8nNgyPxraY',
#    'id': 'VVVBMzNaX1QtdzE3SmYtNHZuSXdSR3NRLndXSUZiZE9MZkZN',
#    'snippet': {'publishedAt': '2022-08-22T10:30:21Z',
#     'channelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ',
#     'title': '【泥泥汝】美腿面前考驗動態視力',
#     'description': '喜歡影片的話幫我按個【喜歡👍】和【訂閱💟】\n開啟【小鈴鐺🔔】才不會錯過新片通知唷！非常感謝 🙏\n影片投稿 ► https://forms.gle/1sRmbEMRhdU83KoLA\n\n泥泥汝 Twitch ► https://bit.ly/3AfNOlQ\n泥泥汝 YouTube ► https://bit.ly/3AaeBAc\n泥泥汝 Instagram ► https://bit.ly/3wmyVx7\n泥泥汝 Facebook ► https://bit.ly/3PJPsSu\n\n#泥泥汝\n#大傑亂剪\n#twitch #twitchstreamer #twitchclips',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/wWIFbdOLfFM/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/wWIFbdOLfFM/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/wWIFbdOLfFM/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/wWIFbdOLfFM/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/wWIFbdOLfFM/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '大傑亂剪',
#     'playlistId': 'UUA33Z_T-w17Jf-4vnIwRGsQ',
#     'position': 12,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'wWIFbdOLfFM'},
#     'videoOwnerChannelTitle': '大傑亂剪',
#     'videoOwnerChannelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ'},
#    'contentDetails': {'videoId': 'wWIFbdOLfFM',
#     'videoPublishedAt': '2022-08-22T10:30:21Z'},
#    'status': {'privacyStatus': 'public'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'dkgvNJXNMK0meHh2xJ9MnAKET6E',
#    'id': 'VVVBMzNaX1QtdzE3SmYtNHZuSXdSR3NRLmZSTzhtSklSYXlz',
#    'snippet': {'publishedAt': '2022-08-21T13:00:31Z',
#     'channelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ',
#     'title': '【妲妲】超自然晃動 戰鬥姐 Megu Megu Fire Endless Night@妲妲DaDa',
#     'description': '喜歡影片的話幫我按個【喜歡👍】和【訂閱💟】\n開啟【小鈴鐺🔔】才不會錯過新片通知唷！非常感謝 🙏\n影片投稿 ► https://forms.gle/1sRmbEMRhdU83KoLA\n\n妲妲 Twitch ► https://bit.ly/3ERyfTa\n妲妲 YouTube ► https://bit.ly/3Ozk8qp\n妲妲 Instagram ► https://bit.ly/3vMUWUI\n妲妲 Facebook ► https://bit.ly/3kimewR\n\n#妲妲 #妲妲咬果凍\n#大傑亂剪\n#twitch #twitchstreamer #twitchclips',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/fRO8mJIRays/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/fRO8mJIRays/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/fRO8mJIRays/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/fRO8mJIRays/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/fRO8mJIRays/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '大傑亂剪',
#     'playlistId': 'UUA33Z_T-w17Jf-4vnIwRGsQ',
#     'position': 13,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'fRO8mJIRays'},
#     'videoOwnerChannelTitle': '大傑亂剪',
#     'videoOwnerChannelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ'},
#    'contentDetails': {'videoId': 'fRO8mJIRays',
#     'videoPublishedAt': '2022-08-21T13:00:31Z'},
#    'status': {'privacyStatus': 'public'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'djgnXVNeNPEy_6fQQFhQNjhc65k',
#    'id': 'VVVBMzNaX1QtdzE3SmYtNHZuSXdSR3NRLnpOMzJVUGIyVGRJ',
#    'snippet': {'publishedAt': '2022-08-21T10:30:10Z',
#     'channelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ',
#     'title': '【薇薇】為什麼要婚前性行為 長相跟技術哪個重要',
#     'description': '喜歡影片的話幫我按個【喜歡👍】和【訂閱💟】\n開啟【小鈴鐺🔔】才不會錯過新片通知唷！非常感謝 🙏\n影片投稿 ► https://forms.gle/1sRmbEMRhdU83KoLA\n\n薇薇 Twitch ► https://bit.ly/3jyBpBL\n薇薇 YouTube ► https://bit.ly/37N6uyO\n薇薇 Instagram ► https://bit.ly/3uP6aJb\n薇薇 Facebook ► https://bit.ly/38Jqpix\n\n#薇薇 #西門夜說 #抱歉了西門\n#大傑亂剪\n#twitch #twitchstreamer #twitchclips',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/zN32UPb2TdI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/zN32UPb2TdI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/zN32UPb2TdI/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/zN32UPb2TdI/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/zN32UPb2TdI/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '大傑亂剪',
#     'playlistId': 'UUA33Z_T-w17Jf-4vnIwRGsQ',
#     'position': 14,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'zN32UPb2TdI'},
#     'videoOwnerChannelTitle': '大傑亂剪',
#     'videoOwnerChannelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ'},
#    'contentDetails': {'videoId': 'zN32UPb2TdI',
#     'videoPublishedAt': '2022-08-21T10:30:10Z'},
#    'status': {'privacyStatus': 'public'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'jx_AMg7g0tru6svi4jHsnYdPoz4',
#    'id': 'VVVBMzNaX1QtdzE3SmYtNHZuSXdSR3NRLmFJbndLcDVEQXYw',
#    'snippet': {'publishedAt': '2022-08-20T13:00:01Z',
#     'channelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ',
#     'title': '【赤鬼伯伯】遇到這秘書 你還能專心工作嗎 02搖 2 Phut Hon',
#     'description': '喜歡影片的話幫我按個【喜歡👍】和【訂閱💟】\n開啟【小鈴鐺🔔】才不會錯過新片通知唷！非常感謝 🙏\n影片投稿 ► https://forms.gle/1sRmbEMRhdU83KoLA\n\n赤鬼伯伯 Twitch ► https://bit.ly/3KjZB5P\n赤鬼伯伯 YouTube ► https://bit.ly/3KrG8Aa\n赤鬼伯伯 Instagram ► https://bit.ly/3OCqlSe\n赤鬼伯伯 Facebook ► https://bit.ly/3kEu1W5\n\n#赤鬼伯伯 #赤鬼\n#大傑亂剪\n#twitch #twitchstreamer #twitchclips',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/aInwKp5DAv0/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/aInwKp5DAv0/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/aInwKp5DAv0/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/aInwKp5DAv0/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/aInwKp5DAv0/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '大傑亂剪',
#     'playlistId': 'UUA33Z_T-w17Jf-4vnIwRGsQ',
#     'position': 15,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'aInwKp5DAv0'},
#     'videoOwnerChannelTitle': '大傑亂剪',
#     'videoOwnerChannelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ'},
#    'contentDetails': {'videoId': 'aInwKp5DAv0',
#     'videoPublishedAt': '2022-08-20T13:00:01Z'},
#    'status': {'privacyStatus': 'public'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'iSmh2pd2Cx2QML8O3hkRg92UA2k',
#    'id': 'VVVBMzNaX1QtdzE3SmYtNHZuSXdSR3NRLnJMaHByTTJyd0ZF',
#    'snippet': {'publishedAt': '2022-08-20T10:30:14Z',
#     'channelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ',
#     'title': '【酪梨歐】看到鬼',
#     'description': '喜歡影片的話幫我按個【喜歡👍】和【訂閱💟】\n開啟【小鈴鐺🔔】才不會錯過新片通知唷！非常感謝 🙏\n影片投稿 ► https://forms.gle/1sRmbEMRhdU83KoLA\n\n酪梨歐 Twitch ► https://bit.ly/3GbbMl2\n酪梨歐 YouTube ► https://bit.ly/3sLG9IX\n酪梨歐 Instagram ► https://bit.ly/39LWas1\n酪梨歐 Facebook ► https://bit.ly/39F2vFw\n\n#酪梨歐 #酪梨\n#大傑亂剪\n#twitch #twitchstreamer #twitchclips',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/rLhprM2rwFE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/rLhprM2rwFE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/rLhprM2rwFE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '大傑亂剪',
#     'playlistId': 'UUA33Z_T-w17Jf-4vnIwRGsQ',
#     'position': 16,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'rLhprM2rwFE'},
#     'videoOwnerChannelTitle': '大傑亂剪',
#     'videoOwnerChannelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ'},
#    'contentDetails': {'videoId': 'rLhprM2rwFE',
#     'videoPublishedAt': '2022-08-20T10:30:14Z'},
#    'status': {'privacyStatus': 'public'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': '1gl3r8u2tlVW5fge7LuHFBsyILc',
#    'id': 'VVVBMzNaX1QtdzE3SmYtNHZuSXdSR3NRLkpuVnpIZW9CbXlJ',
#    'snippet': {'publishedAt': '2022-08-19T13:00:12Z',
#     'channelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ',
#     'title': '【薇薇】穿這件看起來有點大 狗幹硬 Kokain',
#     'description': '💗【工商時間】推薦超辣、性感、美腿正妹直播交友app\n🔥  footseen直播app下載 👉 https://bit.ly/3PbD0L0\n💰 使用上方連結安裝註冊即可免費獲得點數（露水）\n\n喜歡影片的話幫我按個【喜歡👍】和【訂閱💟】\n開啟【小鈴鐺🔔】才不會錯過新片通知唷！非常感謝 🙏\n影片投稿 ► https://forms.gle/1sRmbEMRhdU83KoLA\n\n薇薇 Twitch ► https://bit.ly/3jyBpBL\n薇薇 YouTube ► https://bit.ly/37N6uyO\n薇薇 Instagram ► https://bit.ly/3uP6aJb\n薇薇 Facebook ► https://bit.ly/38Jqpix\n\n#薇薇 #西門夜說 #抱歉了西門\n#大傑亂剪\n#twitch #twitchstreamer #twitchclips',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/JnVzHeoBmyI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/JnVzHeoBmyI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/JnVzHeoBmyI/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/JnVzHeoBmyI/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/JnVzHeoBmyI/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '大傑亂剪',
#     'playlistId': 'UUA33Z_T-w17Jf-4vnIwRGsQ',
#     'position': 17,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'JnVzHeoBmyI'},
#     'videoOwnerChannelTitle': '大傑亂剪',
#     'videoOwnerChannelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ'},
#    'contentDetails': {'videoId': 'JnVzHeoBmyI',
#     'videoPublishedAt': '2022-08-19T13:00:12Z'},
#    'status': {'privacyStatus': 'public'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'xrkkfz9Lkjbhok_hVDCIlVBFqcA',
#    'id': 'VVVBMzNaX1QtdzE3SmYtNHZuSXdSR3NRLm5iTXRJYWlVQVZn',
#    'snippet': {'publishedAt': '2022-08-19T11:14:24Z',
#     'channelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ',
#     'title': '【妲妲】這是能免費看的嗎 老公都出來了',
#     'description': '喜歡影片的話幫我按個【喜歡👍】和【訂閱💟】\n開啟【小鈴鐺🔔】才不會錯過新片通知唷！非常感謝 🙏\n影片投稿 ► https://forms.gle/1sRmbEMRhdU83KoLA\n\n妲妲 Twitch ► https://bit.ly/3ERyfTa\n妲妲 YouTube ► https://bit.ly/3Ozk8qp\n妲妲 Instagram ► https://bit.ly/3vMUWUI\n妲妲 Facebook ► https://bit.ly/3kimewR\n\n#妲妲 #妲妲咬果凍\n#大傑亂剪\n#twitch #twitchstreamer #twitchclips',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/nbMtIaiUAVg/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/nbMtIaiUAVg/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/nbMtIaiUAVg/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/nbMtIaiUAVg/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/nbMtIaiUAVg/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '大傑亂剪',
#     'playlistId': 'UUA33Z_T-w17Jf-4vnIwRGsQ',
#     'position': 18,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'nbMtIaiUAVg'},
#     'videoOwnerChannelTitle': '大傑亂剪',
#     'videoOwnerChannelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ'},
#    'contentDetails': {'videoId': 'nbMtIaiUAVg',
#     'videoPublishedAt': '2022-08-19T11:14:24Z'},
#    'status': {'privacyStatus': 'public'}},
#   {'kind': 'youtube#playlistItem',
#    'etag': 'xgPtZqb56Jz_21xyWkoWDETrhXs',
#    'id': 'VVVBMzNaX1QtdzE3SmYtNHZuSXdSR3NRLlNYWHFLQll4THZF',
#    'snippet': {'publishedAt': '2022-08-18T13:00:30Z',
#     'channelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ',
#     'title': '【酪梨歐】超跑情人夢',
#     'description': '💗【工商時間】推薦超辣、性感、美腿正妹直播交友app\n🔥  footseen直播app下載 👉 https://bit.ly/3PbD0L0\n💰 使用上方連結安裝註冊即可免費獲得點數（露水）\n\n喜歡影片的話幫我按個【喜歡👍】和【訂閱💟】\n開啟【小鈴鐺🔔】才不會錯過新片通知唷！非常感謝 🙏\n影片投稿 ► https://forms.gle/1sRmbEMRhdU83KoLA\n\n酪梨歐 Twitch ► https://bit.ly/3GbbMl2\n酪梨歐 YouTube ► https://bit.ly/3sLG9IX\n酪梨歐 Instagram ► https://bit.ly/39LWas1\n酪梨歐 Facebook ► https://bit.ly/39F2vFw\n\n#酪梨歐 #酪梨\n#大傑亂剪\n#twitch #twitchstreamer #twitchclips',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/SXXqKBYxLvE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/SXXqKBYxLvE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/SXXqKBYxLvE/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/SXXqKBYxLvE/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/SXXqKBYxLvE/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '大傑亂剪',
#     'playlistId': 'UUA33Z_T-w17Jf-4vnIwRGsQ',
#     'position': 19,
#     'resourceId': {'kind': 'youtube#video', 'videoId': 'SXXqKBYxLvE'},
#     'videoOwnerChannelTitle': '大傑亂剪',
#     'videoOwnerChannelId': 'UCA33Z_T-w17Jf-4vnIwRGsQ'},
#    'contentDetails': {'videoId': 'SXXqKBYxLvE',
#     'videoPublishedAt': '2022-08-18T13:00:30Z'},
#    'status': {'privacyStatus': 'public'}}],
#  'pageInfo': {'totalResults': 189, 'resultsPerPage': 20}}

# %%
len(play_list['items'])
# Out:
# 20

# %%
videoId = []
for info in play_list['items']:
    video_id = info['contentDetails'].get('videoId')
    videoId.append(video_id)
videoId
# Out:
# ['2bUyEcCFrRw',
#  'wOLjyZSb3Ig',
#  'vSmR5kOKPdY',
#  'SIxdvnmIBJ0',
#  '7jadIik6Pm0',
#  'D2qevhlkdHU',
#  '8vyJuXmrjA0',
#  'aundT-ma3tg',
#  'E-F3HvX_zQ8',
#  'auA7-0YMZuI',
#  'Ou1aa9wnsA0',
#  '9yybcjDqxMM',
#  'wWIFbdOLfFM',
#  'fRO8mJIRays',
#  'zN32UPb2TdI',
#  'aInwKp5DAv0',
#  'rLhprM2rwFE',
#  'JnVzHeoBmyI',
#  'nbMtIaiUAVg',
#  'SXXqKBYxLvE']

# %%
def get_video_init(video: str, api_key: str):
    url_video = f'https://www.googleapis.com/youtube/v3/videos?id={video}&key={api_key}&part=snippet'
    response_video = requests.get(url_video)
    response_video = response_video.json()
    
    channelId = (response_video['items'][0]).get('snippet').get('channelId')
    channelTitle = (response_video['items'][0]).get('snippet').get('channelTitle')
    print(channelId, '\n', channelTitle)

    url_channel = f'https://www.googleapis.com/youtube/v3/channels?part=contentDetails&id={channelId}&key={api_key}'
    response_channel = requests.get(url_channel)
    response_channel = response_channel.json()
    

    playListId = response_channel['items'][0].get('contentDetails').get('relatedPlaylists').get('uploads')

    url_playlist = f'https://www.googleapis.com/youtube/v3/playlistItems?part=snippet,contentDetails,status&playlistId={playListId}&key={api_key}&maxResults=20'
    response_playlist = requests.get(url_playlist)
    response_playlist = response_playlist.json()

    videoId = []
    for info in response_playlist['items']:
        video_id = info['contentDetails'].get('videoId')
        videoId.append(video_id)
    return channelId, channelTitle, videoId

# %%
# test_1

id, title, video = get_video_init('vSmR5kOKPdY', YOUTUBE_API_KEY)
print(f'{id}\n{title}\n{video}\n----------------------------------')

#test_2
id, title, video = get_video_init('UUvwj5uketM', YOUTUBE_API_KEY)
print(f'{id}\n{title}\n{video}\n----------------------------------')

# test_3
id, title, video = get_video_init('ItYPA2Pw8aY', YOUTUBE_API_KEY)
print(f'{id}\n{title}\n{video}\n----------------------------------')
# Out:
# UCA33Z_T-w17Jf-4vnIwRGsQ
#  大傑亂剪
# UCA33Z_T-w17Jf-4vnIwRGsQ
# 大傑亂剪
# ['2bUyEcCFrRw', 'wOLjyZSb3Ig', 'vSmR5kOKPdY', 'SIxdvnmIBJ0', '7jadIik6Pm0', 'D2qevhlkdHU', '8vyJuXmrjA0', 'aundT-ma3tg', 'E-F3HvX_zQ8', 'auA7-0YMZuI', 'Ou1aa9wnsA0', '9yybcjDqxMM', 'wWIFbdOLfFM', 'fRO8mJIRays', 'zN32UPb2TdI', 'aInwKp5DAv0', 'rLhprM2rwFE', 'JnVzHeoBmyI', 'nbMtIaiUAVg', 'SXXqKBYxLvE']
# ----------------------------------
# UCJaYHlaVhX4SZ11l_6whtbw
#  NBA畫上星號
# UCJaYHlaVhX4SZ11l_6whtbw
# NBA畫上星號
# ['UUvwj5uketM', '7aJYgB06LG4', 'l7dxmUfN_Lg', 'xWptPcqHU74', 'uDGHDmpASd4', 'pXnpZW8IFHc', 'R0HMcIlsAJc', 'g-1VDzuJTdM', 'YkcEL_iCgKU', 'Dupk0yPUFUs', 'JS4wJBdYB6o', '0vOzM114UDQ', 'e9emP2v-0H4', 'd-l8KClMpdg', 'DovnvCUVGYY', 'boaeFTzrbGM', 'g42KOQrea1w', 'B_6pWfCftws', '2Hp_JtBcgGU', 'VbIbr4ygGNs']
# ----------------------------------
# UCPYNvBYZ8ClPPJ6274K4rVA
#  貝莉莓41_V Clip
# UCPYNvBYZ8ClPPJ6274K4rVA
# 貝莉莓41_V Clip
# ['ItYPA2Pw8aY', '-0d6XwOQQ8k', 'gtpDMtlw5uE', 'cMvouxbs6C8', 'HByOA_kEvbU', 'b1mhGLf92To', 'vlxJJFDwZK8', 'Gw0LB8iEGIY', '46WqShpxs9I', 'OCm3cZ2nbeI', 'ekH3EqI_bnM', 'MsDX8tG6dy0', 'YyJ_pJBCWzU', 'DyfVsORvb3c', 'wkenSbVP7YE', '_q3JpkausOw', 'vgji3sDSzpE', 'g_tq5mDyZtA', '03sjxHuQZwY', 'h80P3qumLtc']
# ----------------------------------
