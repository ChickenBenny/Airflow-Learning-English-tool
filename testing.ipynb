# %%
import requests
import pandas as pd

YOUTUBE_API_KEY = 'AIzaSyCjrRrjV8qLlTkxNqMbAn8jjlDqXksU_Ec'

# %%
from googleapiclient.discovery import build


youtube = build('youtube', 'v3', developerKey=YOUTUBE_API_KEY)

request = youtube.channels().list(
        part='contentDetails',
        id='UCUog7fcop-dsY1vsfrLuA2A'
        status = ''
    )

response = request.execute()

response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'pEcOdtYPhcUw6VhY-9P6OTymnvI',
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 5},
#  'items': [{'kind': 'youtube#channel',
#    'etag': 'WrOuPV0-jWIPOfyVIJ5U6laawU8',
#    'id': 'UCUog7fcop-dsY1vsfrLuA2A',
#    'contentDetails': {'relatedPlaylists': {'likes': '',
#      'uploads': 'UUUog7fcop-dsY1vsfrLuA2A'}}}]}

# %%
import youtube_dl
from youtube_dl.utils import DownloadError

# %%
ydl = youtube_dl.YoutubeDL()

result = ydl.extract_info(url = 'https://www.youtube.com/watch?v=xYEoR3CS0ZM',
                          download = False)
# Out:
# [youtube] xYEoR3CS0ZM: Downloading webpage

# %%
infos = ['id', 'title', 'channel', 'view_count', 'like_count', 'channel_id', 'duration', 'categories', 'tags']

new_dict = {key: result[key] for key in infos}

# %%
new_dict
# Out:
# {'id': 'xYEoR3CS0ZM',
#  'title': '男生去夜店怎麼做最吸引女生？（Effi快笑死的一集）How to meet friends in a nightclub',
#  'channel': '黑男邱比特',
#  'view_count': 684558,
#  'like_count': 7084,
#  'channel_id': 'UC4GZ1dNQKWWFDQ4IWl4DezA',
#  'duration': 327,
#  'categories': ['Howto & Style'],
#  'tags': []}

# %%
id = 'n-KL3-O6qgE'
url = f'https://www.googleapis.com/youtube/v3/playlistItems?part=snippet,contentDetails,status&playlistId=UUUog7fcop-dsY1vsfrLuA2A&key={YOUTUBE_API_KEY}&maxResults=20'
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'kind': 'youtube#playlistItemListResponse',
#  'etag': 'INGRaGB5uyR10dXIO_t5Ixf7v9U',
#  'nextPageToken': 'EAAaBlBUOkNCUQ',
#  'items': [{'kind': 'youtube#playlistItem',
#    'etag': 'Ub_w6bkCLQeI_5OucVfQ5f792Z0',
#    'id': 'VVVVb2c3ZmNvcC1kc1kxdnNmckx1QTJBLm4tS0wzLU82cWdF',
#    'snippet': {'publishedAt': '2022-08-27T14:26:37Z',
#     'channelId': 'UCUog7fcop-dsY1vsfrLuA2A',
#     'title': '播報看門道》費城人小聯盟李灝宇 升高A第二場就開轟',
#     'description': '謝謝大家 我是小哥 如果您喜歡我的播報 懇請您的按讚訂閱開啟小鈴鐺 期待再相見',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/n-KL3-O6qgE/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/n-KL3-O6qgE/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/n-KL3-O6qgE/hqdefault.jpg',
#       'width': 480,
#       'height': 360}},
#     'channelTitle': '小哥的棒球夾克',
#     'playlistId': 'UUUog7fcop-dsY1vsfrLuA2A',
#     'position': 0,
# ...
